# %%
from main import *



test3
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\jrs41\Desktop\Coding\Spotify\Lyrics from playlists\workbook.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jrs41/Desktop/Coding/Spotify/Lyrics%20from%20playlists/workbook.ipynb#ch0000000?line=0'>1</a> from main import *
#       <a href='vscode-notebook-cell:/c%3A/Users/jrs41/Desktop/Coding/Spotify/Lyrics%20from%20playlists/workbook.ipynb#ch0000000?line=4'>5</a> test2['lyrics'][4]
#
# File c:\Users\jrs41\Desktop\Coding\Spotify\Lyrics from playlists\main.py:10, in <module>
#       <a href='file:///c%3A/Users/jrs41/Desktop/Coding/Spotify/Lyrics%20from%20playlists/main.py?line=1'>2</a> from functions import *
# ...
